# %%
import pickle
import glob

import plot
import utils

# %%
config = utils.parse_config("./config.ini")

# %%
file_paths = glob.glob(config.output_folder + "/*")
file_paths
# Out:
# ['../test\\Abraham_Bloemaert_-_Apollo_and_Diana_Punishing_Niobe_by_Killing_her_Children_-_Google_Art_Project.jpg.pkl',
#  '../test\\Abraham_Bloemaert_-_Venus_and_Adonis_-_Google_Art_Project.jpg.pkl',
#  '../test\\Abraham_Mignon_-_Garland_of_Flowers_-_Google_Art_Project.jpg.pkl',
#  '../test\\Abraham_Staphorst_-_Colonel_Alexander_Popham,_of_Littlecote,_Wiltshire_-_Google_Art_Project.jpg.pkl',
#  '../test\\Abraham_van_Beijeren_-_Still_Life_with_a_Silver_Pitcher_-_Google_Art_Project.jpg.pkl',
#  '../test\\Abraham_van_Beijeren_-_Sumptuous_Still_Life_-_Google_Art_Project.jpg.pkl',
#  '../test\\Abraham_Van_Calraet_-_Two_Horses_-_Google_Art_Project.jpg.pkl',
#  '../test\\Abraham_Van_Calraet_-_White_Horse_in_a_Riding_School_-_Google_Art_Project.jpg.pkl',
#  '../test\\Abraham_Wuchters_-_Christina_of_Sweden_(1626_-_89)_-_Google_Art_Project.jpg.pkl',
#  '../test\\Adam_Pynacker_-_Bridge_in_an_Italian_Landscape_-_Google_Art_Project.jpg.pkl',
# ...

# %%
result = pickle.load(open(file_paths[0],'rb'))

# %%
type(result[0])
# Out:
# dict

# %%
result[0]
# Out:
# {'gauß_depth': 6, 'hist_orientations': 8, 'phog_depth': 3}

# %%
plot.vector(result[1][-1], parameter=result[0])

# %%
plot.testplot(result[1][-1])

# %%
result[1][-1]
# Out:
# array([1.37271321, 1.50685167, 1.49612093, ..., 0.04291747, 0.00763419,
#        0.        ])
